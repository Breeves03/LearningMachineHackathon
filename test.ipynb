# %%
#%run SupervisedCatBoost.ipynb
#%run SupervisedLogisticRegression.ipynb
#%run SupervisedRandomForest.ipynb
#%run SupervisedXGBoost.ipynb
# Out:
# ROC-AUC: 0.8802 (95% CI: 0.8311, 0.9589)
# PR-AUC: 0.6294
# F1 Score: 0.5930
# Matthews CC: 0.4969
